# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Needed Liberary

# %% [markdown]
# **Data Representation**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive"
df=pd.read_csv(f"{path}/dataset/student-por-100k.csv")
# df=pd.read_csv("student-por-100k")
df
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         GP   M   15       U     GT3       T     4     4  services     other
# 1         MS   F   15       R     LE3       T     1     1   at_home  services
# 2         GP   M   16       U     GT3       T     4     4  services  services
# 3         GP   F   15       U     GT3       T     2     2     other     other
# 4         GP   M   15       U     GT3       T     4     2     other     other
# ...      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 99995     GP   F   16       U     LE3       T     1     2     other  services
# 99996     GP   M   17       R     GT3       T     3     2     other     other
# 99997     GP   F   17       U     GT3       T     2     2     other  services
# 99998     GP   F   16       U     GT3       T     2     2  services     other
# 99999     GP   F   16       U     LE3       T     2     2  services  services
#
#        ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      ...      5        3      3     1     1      5        2  12  13  12
# 1      ...      5        4      3     1     2      4        0  10  10  10
# 2      ...      5        3      2     1     2      5        4  14  15  15
# 3      ...      5        1      2     1     1      3        4  10  10  10
# 4      ...      3        3      3     1     1      3        0  11   9  10
# ...    ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 99995  ...      4        4      3     1     1      1        0  13  13  10
# 99996  ...      4        4      4     1     4      3        4   7   6   8
# 99997  ...      4        2      3     1     1      1        8  13  15  15
# 99998  ...      3        4      4     1     4      5        0  13  12  14
# 99999  ...      4        3      3     2     3      4        0  14  13  13
#
# [100000 rows x 33 columns]

# %%
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   M   15       U     GT3       T     4     4  services     other
# 1     MS   F   15       R     LE3       T     1     1   at_home  services
# 2     GP   M   16       U     GT3       T     4     4  services  services
# 3     GP   F   15       U     GT3       T     2     2     other     other
# 4     GP   M   15       U     GT3       T     4     2     other     other
# 5     GP   M   15       U     GT3       T     4     3   teacher     other
# 6     MS   F   17       R     GT3       T     4     4   teacher  services
# 7     GP   M   15       U     GT3       T     2     2  services  services
# 8     MS   M   15       U     GT3       T     3     1     other  services
# 9     GP   F   16       U     GT3       T     4     3    health     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      5        3      3     1     1      5        2  12  13  12
# 1  ...      5        4      3     1     2      4        0  10  10  10
# 2  ...      5        3      2     1     2      5        4  14  15  15
# 3  ...      5        1      2     1     1      3        4  10  10  10
# 4  ...      3        3      3     1     1      3        0  11   9  10
# 5  ...      4        4      1     1     1      1        0  12  13  14
# 6  ...      4        3      3     1     2      5        2  12  12  12
# 7  ...      5        5      4     1     2      5        6  14  13  13
# 8  ...      3        2      3     1     3      4        0  10   9  11
# 9  ...      4        3      5     1     5      2        2  14  14  15
#
# [10 rows x 33 columns]

# %%
df.tail()
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 99995     GP   F   16       U     LE3       T     1     2     other  services
# 99996     GP   M   17       R     GT3       T     3     2     other     other
# 99997     GP   F   17       U     GT3       T     2     2     other  services
# 99998     GP   F   16       U     GT3       T     2     2  services     other
# 99999     GP   F   16       U     LE3       T     2     2  services  services
#
#        ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 99995  ...      4        4      3     1     1      1        0  13  13  10
# 99996  ...      4        4      4     1     4      3        4   7   6   8
# 99997  ...      4        2      3     1     1      1        8  13  15  15
# 99998  ...      3        4      4     1     4      5        0  13  12  14
# 99999  ...      4        3      3     2     3      4        0  14  13  13
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 33 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   school      100000 non-null  object
#  1   sex         100000 non-null  object
#  2   age         100000 non-null  int64
#  3   address     100000 non-null  object
#  4   famsize     100000 non-null  object
#  5   Pstatus     100000 non-null  object
#  6   Medu        100000 non-null  int64
#  7   Fedu        100000 non-null  int64
#  8   Mjob        100000 non-null  object
#  9   Fjob        100000 non-null  object
#  10  reason      100000 non-null  object
#  11  guardian    100000 non-null  object
#  12  traveltime  100000 non-null  int64
#  13  studytime   100000 non-null  int64
#  14  failures    100000 non-null  int64
#  15  schoolsup   100000 non-null  object
#  16  famsup      100000 non-null  object
#  17  paid        100000 non-null  object
#  18  activities  100000 non-null  object
#  19  nursery     100000 non-null  object
#  20  higher      100000 non-null  object
#  21  internet    100000 non-null  object
#  22  romantic    100000 non-null  object
#  23  famrel      100000 non-null  int64
#  24  freetime    100000 non-null  int64
#  25  goout       100000 non-null  int64
#  26  Dalc        100000 non-null  int64
#  27  Walc        100000 non-null  int64
#  28  health      100000 non-null  int64
#  29  absences    100000 non-null  int64
#  30  G1          100000 non-null  int64
#  31  G2          100000 non-null  int64
#  32  G3          100000 non-null  int64
# dtypes: int64(16), object(17)
# memory usage: 25.2+ MB

# %%
df.describe()
# Out:
#                  age           Medu           Fedu     traveltime  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       16.748490       2.511690       2.307900       1.569970
# std         1.215988       1.133427       1.100441       0.748178
# min        15.000000       0.000000       0.000000       1.000000
# 25%        16.000000       2.000000       1.000000       1.000000
# 50%        17.000000       2.000000       2.000000       1.000000
# 75%        18.000000       4.000000       3.000000       2.000000
# max        22.000000       4.000000       4.000000       4.000000
#
#            studytime       failures         famrel       freetime  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        1.929340       0.221920       3.929180       3.178120
# std         0.829635       0.591638       0.953747       1.051106
# min         1.000000       0.000000       1.000000       1.000000
# 25%         1.000000       0.000000       4.000000       3.000000
# 50%         2.000000       0.000000       4.000000       3.000000
# 75%         2.000000       0.000000       5.000000       4.000000
# max         4.000000       3.000000       5.000000       5.000000
#
#                goout           Dalc          Walc         health  \
# count  100000.000000  100000.000000  100000.00000  100000.000000
# mean        3.190930       1.503750       2.28465       3.531880
# std         1.177085       0.924811       1.28695       1.446964
# min         1.000000       1.000000       1.00000       1.000000
# 25%         2.000000       1.000000       1.00000       2.000000
# 50%         3.000000       1.000000       2.00000       4.000000
# 75%         4.000000       2.000000       3.00000       5.000000
# max         5.000000       5.000000       5.00000       5.000000
#
#             absences             G1             G2             G3
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        3.661310      11.404620      11.569120      11.916100
# std         4.597494       2.750461       2.927536       3.228988
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000      10.000000      10.000000      10.000000
# 50%         2.000000      11.000000      11.000000      12.000000
# 75%         6.000000      13.000000      13.000000      14.000000
# max        32.000000      19.000000      19.000000      19.000000

# %%
df.describe(include="O")
# Out:
#         school     sex address famsize Pstatus    Mjob    Fjob  reason  \
# count   100000  100000  100000  100000  100000  100000  100000  100000
# unique       2       2       2       2       2       5       5       4
# top         GP       F       U     GT3       T   other   other  course
# freq     65286   59007   69696   70244   87719   39779   56687   44038
#
#        guardian schoolsup  famsup    paid activities nursery  higher internet  \
# count    100000    100000  100000  100000     100000  100000  100000   100000
# unique        3         2       2       2          2       2       2        2
# top      mother        no     yes      no         no     yes     yes      yes
# freq      70202     89512   61547   94016      51516   80269   89303    76885
#
#        romantic
# count    100000
# unique        2
# top          no
# freq      63441

# %% [markdown]
# **Handle Duplicate values**

# %%
df.duplicated().sum()
# Out:
# np.int64(99351)

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# # Aggregating Absences Data in a DataFrame

# %%
df["absences"].agg(["max" , "min" , "mean"])
# Out:
# max     32.00000
# min      0.00000
# mean     3.66131
# Name: absences, dtype: float64

# %%
df['Avg Score']= ((df['G1']+df['G2']+df['G3'])/3)
df
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         GP   M   15       U     GT3       T     4     4  services     other
# 1         MS   F   15       R     LE3       T     1     1   at_home  services
# 2         GP   M   16       U     GT3       T     4     4  services  services
# 3         GP   F   15       U     GT3       T     2     2     other     other
# 4         GP   M   15       U     GT3       T     4     2     other     other
# ...      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 99995     GP   F   16       U     LE3       T     1     2     other  services
# 99996     GP   M   17       R     GT3       T     3     2     other     other
# 99997     GP   F   17       U     GT3       T     2     2     other  services
# 99998     GP   F   16       U     GT3       T     2     2  services     other
# 99999     GP   F   16       U     LE3       T     2     2  services  services
#
#        ... freetime goout  Dalc  Walc  health absences  G1  G2  G3  Avg Score
# 0      ...        3     3     1     1       5        2  12  13  12  12.333333
# 1      ...        4     3     1     2       4        0  10  10  10  10.000000
# 2      ...        3     2     1     2       5        4  14  15  15  14.666667
# 3      ...        1     2     1     1       3        4  10  10  10  10.000000
# 4      ...        3     3     1     1       3        0  11   9  10  10.000000
# ...    ...      ...   ...   ...   ...     ...      ...  ..  ..  ..        ...
# 99995  ...        4     3     1     1       1        0  13  13  10  12.000000
# 99996  ...        4     4     1     4       3        4   7   6   8   7.000000
# 99997  ...        2     3     1     1       1        8  13  15  15  14.333333
# 99998  ...        4     4     1     4       5        0  13  12  14  13.000000
# 99999  ...        3     3     2     3       4        0  14  13  13  13.333333
#
# [100000 rows x 34 columns]

# %%
df["Performance Category"] = pd.qcut(df["Avg Score"] , q=3 , labels=["Low" , "Medium" , "High"])
df
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         GP   M   15       U     GT3       T     4     4  services     other
# 1         MS   F   15       R     LE3       T     1     1   at_home  services
# 2         GP   M   16       U     GT3       T     4     4  services  services
# 3         GP   F   15       U     GT3       T     2     2     other     other
# 4         GP   M   15       U     GT3       T     4     2     other     other
# ...      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 99995     GP   F   16       U     LE3       T     1     2     other  services
# 99996     GP   M   17       R     GT3       T     3     2     other     other
# 99997     GP   F   17       U     GT3       T     2     2     other  services
# 99998     GP   F   16       U     GT3       T     2     2  services     other
# 99999     GP   F   16       U     LE3       T     2     2  services  services
#
#        ... goout Dalc  Walc  health  absences  G1  G2  G3  Avg Score  \
# 0      ...     3    1     1       5         2  12  13  12  12.333333
# 1      ...     3    1     2       4         0  10  10  10  10.000000
# 2      ...     2    1     2       5         4  14  15  15  14.666667
# 3      ...     2    1     1       3         4  10  10  10  10.000000
# 4      ...     3    1     1       3         0  11   9  10  10.000000
# ...    ...   ...  ...   ...     ...       ...  ..  ..  ..        ...
# 99995  ...     3    1     1       1         0  13  13  10  12.000000
# 99996  ...     4    1     4       3         4   7   6   8   7.000000
# 99997  ...     3    1     1       1         8  13  15  15  14.333333
# 99998  ...     4    1     4       5         0  13  12  14  13.000000
# 99999  ...     3    2     3       4         0  14  13  13  13.333333
#
#       Performance Category
# 0                   Medium
# 1                      Low
# 2                     High
# 3                      Low
# 4                      Low
# ...                    ...
# 99995               Medium
# 99996                  Low
# 99997                 High
# 99998                 High
# 99999                 High
#
# [100000 rows x 35 columns]

# %%
pivot=df.pivot_table(index='Mjob',values='Avg Score',aggfunc='mean')
pivot
# Out:
#           Avg Score
# Mjob
# at_home   10.739171
# health    12.690864
# other     11.469662
# services  11.810901
# teacher   12.818988

# %%
pivot=df.pivot_table(index='Fjob',values='Avg Score',aggfunc='mean')
pivot
# Out:
#           Avg Score
# Fjob
# at_home   10.913939
# health    12.218346
# other     11.610069
# services  11.419382
# teacher   13.354712

# %%
pivot=df.pivot_table(index='Pstatus',values='Avg Score',aggfunc='mean')
pivot
# Out:
#          Avg Score
# Pstatus
# A        11.548082
# T        11.641408

# %%
pivot=df.pivot_table(index='internet',values='Avg Score',aggfunc='mean')
pivot
# Out:
#           Avg Score
# internet
# no        10.856269
# yes       11.862548

# %%
pivot=df.pivot_table(index='higher',values='Avg Score',aggfunc='mean')
pivot
# Out:
#         Avg Score
# higher
# no       8.706429
# yes     11.980135

# %%
pivot=df.pivot_table(index='school',values='failures',aggfunc='mean')
pivot
# Out:
#         failures
# school
# GP      0.173268
# MS      0.313418

# %%
pivot=df.pivot_table(index='school',values='Avg Score',aggfunc='mean')
pivot
# Out:
#         Avg Score
# school
# GP      12.230340
# MS      10.500797

# %%
df[df["famsize"].isin(["GT3"])]
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         GP   M   15       U     GT3       T     4     4  services     other
# 2         GP   M   16       U     GT3       T     4     4  services  services
# 3         GP   F   15       U     GT3       T     2     2     other     other
# 4         GP   M   15       U     GT3       T     4     2     other     other
# 5         GP   M   15       U     GT3       T     4     3   teacher     other
# ...      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 99993     GP   M   16       U     GT3       T     1     0     other     other
# 99994     GP   F   16       U     GT3       T     4     4    health    health
# 99996     GP   M   17       R     GT3       T     3     2     other     other
# 99997     GP   F   17       U     GT3       T     2     2     other  services
# 99998     GP   F   16       U     GT3       T     2     2  services     other
#
#        ... goout Dalc  Walc  health  absences  G1  G2  G3  Avg Score  \
# 0      ...     3    1     1       5         2  12  13  12  12.333333
# 2      ...     2    1     2       5         4  14  15  15  14.666667
# 3      ...     2    1     1       3         4  10  10  10  10.000000
# 4      ...     3    1     1       3         0  11   9  10  10.000000
# 5      ...     1    1     1       1         0  12  13  14  13.000000
# ...    ...   ...  ...   ...     ...       ...  ..  ..  ..        ...
# 99993  ...     2    1     1       3         0  16  17  18  17.000000
# 99994  ...     2    1     1       3         0  16  16  17  16.333333
# 99996  ...     4    1     4       3         4   7   6   8   7.000000
# 99997  ...     3    1     1       1         8  13  15  15  14.333333
# 99998  ...     4    1     4       5         0  13  12  14  13.000000
#
#       Performance Category
# 0                   Medium
# 2                     High
# 3                      Low
# 4                      Low
# 5                     High
# ...                    ...
# 99993                 High
# 99994                 High
# 99996                  Low
# 99997                 High
# 99998                 High
#
# [70244 rows x 35 columns]

# %% [markdown]
# # univariate analysis

# %%
mj =df['Mjob'].value_counts()
mj
# Out:
# Mjob
# other       39779
# services    20982
# at_home     20739
# teacher     11130
# health       7370
# Name: count, dtype: int64

# %%
plt.bar(mj.index ,mj.values ,color ='purple' )
plt.title('Mjob Distribution')
plt.xlabel('Mjob')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
colors = plt.cm.tab10.colors[:len(mj)]

plt.pie(x=mj, labels=mj.index, autopct="%0.0f%%", shadow=True, colors=colors)
plt.title('Mjob')
plt.legend(loc=1)
plt.show()

# %%
df
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         GP   M   15       U     GT3       T     4     4  services     other
# 1         MS   F   15       R     LE3       T     1     1   at_home  services
# 2         GP   M   16       U     GT3       T     4     4  services  services
# 3         GP   F   15       U     GT3       T     2     2     other     other
# 4         GP   M   15       U     GT3       T     4     2     other     other
# ...      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 99995     GP   F   16       U     LE3       T     1     2     other  services
# 99996     GP   M   17       R     GT3       T     3     2     other     other
# 99997     GP   F   17       U     GT3       T     2     2     other  services
# 99998     GP   F   16       U     GT3       T     2     2  services     other
# 99999     GP   F   16       U     LE3       T     2     2  services  services
#
#        ... goout Dalc  Walc  health  absences  G1  G2  G3  Avg Score  \
# 0      ...     3    1     1       5         2  12  13  12  12.333333
# 1      ...     3    1     2       4         0  10  10  10  10.000000
# 2      ...     2    1     2       5         4  14  15  15  14.666667
# 3      ...     2    1     1       3         4  10  10  10  10.000000
# 4      ...     3    1     1       3         0  11   9  10  10.000000
# ...    ...   ...  ...   ...     ...       ...  ..  ..  ..        ...
# 99995  ...     3    1     1       1         0  13  13  10  12.000000
# 99996  ...     4    1     4       3         4   7   6   8   7.000000
# 99997  ...     3    1     1       1         8  13  15  15  14.333333
# 99998  ...     4    1     4       5         0  13  12  14  13.000000
# 99999  ...     3    2     3       4         0  14  13  13  13.333333
#
#       Performance Category
# 0                   Medium
# 1                      Low
# 2                     High
# 3                      Low
# 4                      Low
# ...                    ...
# 99995               Medium
# 99996                  Low
# 99997                 High
# 99998                 High
# 99999                 High
#
# [100000 rows x 35 columns]

# %%
Fjob=df['Fjob'].value_counts()
Fjob
# Out:
# Fjob
# other       56687
# services    27686
# at_home      6538
# teacher      5535
# health       3554
# Name: count, dtype: int64

# %%
plt.bar(mj.index ,mj.values ,color ='purple' )
plt.title('Fjob Distribution')
plt.xlabel('Fjob')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.pie(x=Fjob ,labels=Fjob.index ,autopct='%0.0f%%' ,shadow=True,explode=[0,0,0,0.3,0.2])
plt.title('Fjob distribution')
plt.legend(loc=1)

# %%
df
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0         GP   M   15       U     GT3       T     4     4  services     other
# 1         MS   F   15       R     LE3       T     1     1   at_home  services
# 2         GP   M   16       U     GT3       T     4     4  services  services
# 3         GP   F   15       U     GT3       T     2     2     other     other
# 4         GP   M   15       U     GT3       T     4     2     other     other
# ...      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 99995     GP   F   16       U     LE3       T     1     2     other  services
# 99996     GP   M   17       R     GT3       T     3     2     other     other
# 99997     GP   F   17       U     GT3       T     2     2     other  services
# 99998     GP   F   16       U     GT3       T     2     2  services     other
# 99999     GP   F   16       U     LE3       T     2     2  services  services
#
#        ... goout Dalc  Walc  health  absences  G1  G2  G3  Avg Score  \
# 0      ...     3    1     1       5         2  12  13  12  12.333333
# 1      ...     3    1     2       4         0  10  10  10  10.000000
# 2      ...     2    1     2       5         4  14  15  15  14.666667
# 3      ...     2    1     1       3         4  10  10  10  10.000000
# 4      ...     3    1     1       3         0  11   9  10  10.000000
# ...    ...   ...  ...   ...     ...       ...  ..  ..  ..        ...
# 99995  ...     3    1     1       1         0  13  13  10  12.000000
# 99996  ...     4    1     4       3         4   7   6   8   7.000000
# 99997  ...     3    1     1       1         8  13  15  15  14.333333
# 99998  ...     4    1     4       5         0  13  12  14  13.000000
# 99999  ...     3    2     3       4         0  14  13  13  13.333333
#
#       Performance Category
# 0                   Medium
# 1                      Low
# 2                     High
# 3                      Low
# 4                      Low
# ...                    ...
# 99995               Medium
# 99996                  Low
# 99997                 High
# 99998                 High
# 99999                 High
#
# [100000 rows x 35 columns]

# %%
school=df['school'].value_counts()
school
# Out:
# school
# GP    65286
# MS    34714
# Name: count, dtype: int64

# %%
plt.bar(school.index ,school.values ,color ='purple' )
plt.title('school Distribution')
plt.xlabel('school')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.pie(x=school ,labels=school.index ,autopct='%0.0f%%' ,shadow=True,explode=[0.3,0.2])
plt.title('Fjob distribution')
plt.legend(loc=1)

# %%
df["absences"].agg(["min", "max", "mean"])
# Out:
# min      0.00000
# max     32.00000
# mean     3.66131
# Name: absences, dtype: float64

# %%
df[df["absences"] == 75.000000]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3, Avg Score, Performance Category]
# Index: []
#
# [0 rows x 35 columns]

# %%
df[df["absences"]==0.000000]
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1         MS   F   15       R     LE3       T     1     1   at_home  services
# 4         GP   M   15       U     GT3       T     4     2     other     other
# 5         GP   M   15       U     GT3       T     4     3   teacher     other
# 8         MS   M   15       U     GT3       T     3     1     other  services
# 11        MS   F   16       R     GT3       T     1     1     other     other
# ...      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 99993     GP   M   16       U     GT3       T     1     0     other     other
# 99994     GP   F   16       U     GT3       T     4     4    health    health
# 99995     GP   F   16       U     LE3       T     1     2     other  services
# 99998     GP   F   16       U     GT3       T     2     2  services     other
# 99999     GP   F   16       U     LE3       T     2     2  services  services
#
#        ... goout Dalc  Walc  health  absences  G1  G2  G3  Avg Score  \
# 1      ...     3    1     2       4         0  10  10  10  10.000000
# 4      ...     3    1     1       3         0  11   9  10  10.000000
# 5      ...     1    1     1       1         0  12  13  14  13.000000
# 8      ...     3    1     3       4         0  10   9  11  10.000000
# 11     ...     2    1     1       1         0  13  10  13  12.000000
# ...    ...   ...  ...   ...     ...       ...  ..  ..  ..        ...
# 99993  ...     2    1     1       3         0  16  17  18  17.000000
# 99994  ...     2    1     1       3         0  16  16  17  16.333333
# 99995  ...     3    1     1       1         0  13  13  10  12.000000
# 99998  ...     4    1     4       5         0  13  12  14  13.000000
# 99999  ...     3    2     3       4         0  14  13  13  13.333333
#
#       Performance Category
# 1                      Low
# 4                      Low
# 5                     High
# 8                      Low
# 11                  Medium
# ...                    ...
# 99993                 High
# 99994                 High
# 99995               Medium
# 99998                 High
# 99999                 High
#
# [37457 rows x 35 columns]

# %%
absences=df['absences'].value_counts()
absences
# Out:
# absences
# 0     37457
# 2     16812
# 4     14561
# 6      7525
# 8      6481
# 10     3272
# 12     1906
# 5      1875
# 1      1790
# 16     1547
# 14     1208
# 3      1120
# 9      1102
# 11      766
# 7       472
# 18      456
# 21      323
# 15      309
# 22      288
# 13      164
# 26      159
# 30      148
# 24      140
# 32      119
# Name: count, dtype: int64

# %%
plt.bar(absences.index ,absences.values ,color ='purple' )
plt.title('absences Distribution')
plt.xlabel('absences')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
absences = absences.sort_values(ascending=False)


threshold = absences.sum() * 0.03
absences_filtered = absences[absences >= threshold]
other_sum = absences[absences < threshold].sum()
if other_sum > 0:
    absences_filtered["Other"] = other_sum


explode = [0.1 if i < 3 else 0 for i in range(len(absences_filtered))]


colors = plt.cm.get_cmap("tab20").colors[:len(absences_filtered)]


plt.figure(figsize=(12, 12))


wedges, texts, autotexts = plt.pie(
    absences_filtered,
    labels=absences_filtered.index,
    autopct='%0.1f%%',
    shadow=True,
    colors=colors,
    startangle=140,
    pctdistance=0.6,
    labeldistance=1.1,
    explode=explode
)


for text in texts:
    text.set_fontsize(14)
for autotext in autotexts:
    autotext.set_fontsize(14)


plt.title('Absences Distribution', fontsize=18)


plt.legend(wedges, absences_filtered.index, title="Categories", loc="center left", bbox_to_anchor=(1, 0.5), fontsize=12)

plt.show()
# Out:
# /tmp/ipython-input-16375/1082061321.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap("tab20").colors[:len(absences_filtered)]

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    plt.figure(figsize=(8, 15))
    values = df[col].value_counts()
    plt.pie(values, labels=values.index, autopct='%.1f%%', shadow=False)
    plt.title(f'{col} students')
    plt.show()

# %% [markdown]
# #Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df.select_dtypes(include="object").columns
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
df["sex"] = le.fit_transform(df["sex"])
df["sex"].value_counts()
# Out:
# sex
# 0    59007
# 1    40993
# Name: count, dtype: int64

# %%
df["school"] = le.fit_transform(df["school"])
df["school"].value_counts()
# Out:
# school
# 0    65286
# 1    34714
# Name: count, dtype: int64

# %%
for col in df.select_dtypes(include=["object", "category"]).columns:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    1   15        1        0        1     4     4     3     2  ...
# 1       1    0   15        0        1        1     1     1     0     3  ...
# 2       0    1   16        1        0        1     4     4     3     3  ...
# 3       0    0   15        1        0        1     2     2     2     2  ...
# 4       0    1   15        1        0        1     4     2     2     2  ...
#
#    goout  Dalc  Walc  health  absences  G1  G2  G3  Avg Score  \
# 0      3     1     1       5         2  12  13  12  12.333333
# 1      3     1     2       4         0  10  10  10  10.000000
# 2      2     1     2       5         4  14  15  15  14.666667
# 3      2     1     1       3         4  10  10  10  10.000000
# 4      3     1     1       3         0  11   9  10  10.000000
#
#    Performance Category
# 0                     2
# 1                     1
# 2                     0
# 3                     1
# 4                     1
#
# [5 rows x 35 columns]

# %% [markdown]
# #Feature selection

# %%
target = "G3"

# %%
df = df.drop(["Avg Score", "Performance Category"], axis=1)

# %%
X = df.drop("G3", axis=1)
y = df["G3"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (100000, 32)
# (100000,)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), cmap="coolwarm")
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=42)
rf.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
import pandas as pd

importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
}).sort_values(by="Importance", ascending=False)

importance
# Out:
#        Feature  Importance
# 31          G2    0.846832
# 29    absences    0.020862
# 23      famrel    0.015736
# 26        Dalc    0.010747
# 10      reason    0.009245
# 2          age    0.008889
# 12  traveltime    0.008494
# 30          G1    0.008013
# 25       goout    0.007515
# 28      health    0.006949
# 24    freetime    0.006372
# 9         Fjob    0.005986
# 1          sex    0.005796
# 27        Walc    0.005160
# 14    failures    0.004376
# 8         Mjob    0.003744
# 11    guardian    0.003645
# 0       school    0.003049
# 6         Medu    0.002918
# 13   studytime    0.002881
# 4      famsize    0.002614
# 7         Fedu    0.002499
# 18  activities    0.001624
# 22    romantic    0.001275
# 19     nursery    0.000936
# 3      address    0.000865
# 16      famsup    0.000728
# 17        paid    0.000612
# 15   schoolsup    0.000580
# 5      Pstatus    0.000491
# 21    internet    0.000335
# 20      higher    0.000230

# %%
plt.figure(figsize=(10,6))
plt.barh(importance["Feature"], importance["Importance"])
plt.gca().invert_yaxis()
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, f_regression

selector = SelectKBest(score_func=f_regression, k=3)
X_selected = selector.fit_transform(X, y)

# %%
selected_features = X.columns[selector.get_support()]
print(selected_features)
# Out:
# Index(['failures', 'G1', 'G2'], dtype='object')

# %%
X = X[selected_features]

# %% [markdown]
# #Train–Test Split

# %%
X = df[selected_features]
y = df["G3"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,          # input features
    y,          # output
    test_size=0.2,   # 20% testing
    random_state=42  # same result every time
)

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (80000, 3)
# X_test : (20000, 3)
# y_train: (80000,)
# y_test : (20000,)

# %% [markdown]
# #Model Training

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

print("R2 Score:", r2_score(y_test, y_pred_lr))
print("MAE:", mean_absolute_error(y_test, y_pred_lr))
# Out:
# R2 Score: 0.8522197187021908
# MAE: 0.7843409166189804

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
y_pred_rf = rf.predict(X_test)

# %%
print("R2 Score:", r2_score(y_test, y_pred_rf))
print("MAE:", mean_absolute_error(y_test, y_pred_rf))
# Out:
# R2 Score: 0.9184216013635571
# MAE: 0.6027596889093264

# %% [markdown]
# GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=3,
    random_state=42
)

gbr.fit(X_train, y_train)

pred_gbr = gbr.predict(X_test)

print("GBR Accuracy:", r2_score(y_test, pred_gbr)*100)
# Out:
# GBR Accuracy: 89.34584125335935

# %%
from sklearn.linear_model import (
    LinearRegression,
    Ridge,
    Lasso,
    ElasticNet
)

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    ExtraTreesRegressor,
    AdaBoostRegressor
)

from sklearn.neighbors import KNeighborsRegressor

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(alpha=1.0),
    "Lasso Regression": Lasso(alpha=0.01),
    "ElasticNet": ElasticNet(alpha=0.01),

    "Decision Tree": DecisionTreeRegressor(random_state=42),

    "Random Forest": RandomForestRegressor(
        n_estimators=300, random_state=42
    ),

    "Extra Trees": ExtraTreesRegressor(
        n_estimators=300, random_state=42
    ),

    "Gradient Boosting": GradientBoostingRegressor(
        n_estimators=200, learning_rate=0.05, random_state=42
    ),

    "AdaBoost": AdaBoostRegressor(
        n_estimators=200, random_state=42
    ),

    "KNN Regressor": KNeighborsRegressor(n_neighbors=5)
}

# %%
from sklearn.metrics import r2_score, mean_absolute_error

results = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = r2_score(y_test, y_pred) * 100
    mae = mean_absolute_error(y_test, y_pred)
    results[name] = round(accuracy, 2)
    print(f"{name:30s} | R2: {accuracy:.2f}% | MAE: {mae:.4f}")

print("\nBest Model:", max(results, key=results.get),
      "with", max(results.values()), "% accuracy")
# Out:
# Linear Regression              | R2: 85.22% | MAE: 0.7843
# Ridge Regression               | R2: 85.22% | MAE: 0.7843
# Lasso Regression               | R2: 85.22% | MAE: 0.7835
# ElasticNet                     | R2: 85.22% | MAE: 0.7836
# Decision Tree                  | R2: 91.84% | MAE: 0.6028
# Random Forest                  | R2: 91.84% | MAE: 0.6028
# Extra Trees                    | R2: 91.84% | MAE: 0.6028
# Gradient Boosting              | R2: 89.35% | MAE: 0.6895
# AdaBoost                       | R2: 78.02% | MAE: 1.0344
# KNN Regressor                  | R2: 89.36% | MAE: 0.6274
#
# Best Model: Decision Tree with 91.84 % accuracy

# %%
results_df = pd.DataFrame({
    "Model": results.keys(),
    "Accuracy (%)": results.values()
}).sort_values(by="Accuracy (%)", ascending=False)

results_df
# Out:
#                Model  Accuracy (%)
# 4      Decision Tree         91.84
# 5      Random Forest         91.84
# 6        Extra Trees         91.84
# 9      KNN Regressor         89.36
# 7  Gradient Boosting         89.35
# 0  Linear Regression         85.22
# 1   Ridge Regression         85.22
# 3         ElasticNet         85.22
# 2   Lasso Regression         85.22
# 8           AdaBoost         78.02

# %%
# Save the best model
import os
import joblib

model_folder = f"{path}/model"
os.makedirs(model_folder, exist_ok=True)


best_model_name = max(results, key=results.get)
best_model = models[best_model_name]

model_path = f"{model_folder}/student_performance_model.pkl"
joblib.dump(best_model, model_path)

print(f"Saved {best_model_name} at {model_path} ✅")
# Out:
# Saved Decision Tree at /content/drive/MyDrive/model/student_performance_model.pkl ✅
